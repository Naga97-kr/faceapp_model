# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys 
import time 
import os 
import urllib.request 
import selenium, time, os, zipfile, shutil
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from urllib.request import urlretrieve
from tqdm import tqdm
import warnings
warnings.filterwarnings(action='ignore')

def createFolder(directory): 
    try: 
        if not os.path.exists(directory): 
            os.makedirs(directory) 
    except OSError: 
        print ('Error: Creating directory. ' + directory) 

def image_download(keyword):
    driver = webdriver.Chrome()
    driver.implicitly_wait(3) 
    createFolder('./datasets/'+keyword)
    # ============================================================================= 
    # 구글 이미지 검색 접속 및 검색어 입력 
    # ============================================================================= 
    print(keyword, '검색') 
    driver.get('https://www.google.co.kr/imghp?hl=ko') 

    Keyword=driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input') 
    Keyword.send_keys(keyword) 

    driver.find_element_by_xpath('//*[@id="sbtc"]/button').click() 
    # ============================================================================= 
    # 스크롤 
    # ============================================================================= 
    print(keyword+' 스크롤 중 .............') 
    elem = driver.find_element_by_tag_name("body") 
    for i in range(100): 
        elem.send_keys(Keys.PAGE_DOWN) 
        time.sleep(0.1) 

    try: 
        driver.find_element_by_xpath('//*[@id="islmp"]/div/div/div/div[1]/div[4]/div[2]/input').click() 
        for i in range(60): 
            elem.send_keys(Keys.PAGE_DOWN) 
            time.sleep(0.1) 
    except: 
        pass 

    # ============================================================================= 
    # 이미지 개수 
    # ============================================================================= 
    links=[] 
    images = driver.find_elements_by_css_selector("img.rg_i.Q4LuWd") 
    for image in images: 
        if image.get_attribute('src')!=None and len(links) < 70: 
            links.append(image.get_attribute('src')) 

    print(keyword+' 찾은 이미지 개수:',len(links)) 
    time.sleep(2) 
    # ============================================================================= 
    # 이미지 다운로드 
    # ============================================================================= 
    for k,i in enumerate(links): 
        url = i 
        start = time.time()
        try:
            urllib.request.urlretrieve(url, "./datasets/"+keyword+"/"+keyword+"_"+str(k)+".jpg") 
            print(str(k+1)+'/'+str(len(links))+' '+keyword+' 다운로드 중....... Download time : '+str(time.time() - start)[:5]+' 초')
        except:
            pass

    print(keyword+' ---다운로드 완료---') 
    driver.close()

# %%
querys =['케이윌', '현아', '붐', '선예', '제시카', '쌈디', '청하', '윤상현', '타블로', '휘인', '설현', '신현준', '서태지', '박봄', '장근석', '유재명', '윤승아', '박진영', '김래원', '로꼬', '장윤주', '서현진', '송지효', '김혜윤', '박영진', '정석원', '안재홍', '최진혁', '강하늘', '찬성', '정호연', '김무열', '이성재', '크러쉬', '정용화', '박지성', '예성', '이광수', '조우진', '시우민', '김승우', '려욱', '공민지', '다현', '고두심', '우원재', '이지아', '정인', '송은이', '김종국', '나르샤', '유재환']
querys = list(set(querys))
print(len(querys), querys)
# Out:
# 52 ['케이윌', '현아', '붐', '선예', '제시카', '쌈디', '청하', '윤상현', '타블로', '휘인', '설현', '신현준', '서태지', '박봄', '장근석', '유재명', '윤승아', '박진영', '김래원', '로꼬', '장윤주', '서현진', '송지효', '김혜윤', '송은이', '박영진', '정석원', '안재홍', '최진혁', '강하늘', '찬성', '정호연', '김무열', '이성재', '크러쉬', '정용화', '예성', '이광수', '조우진', '시우민', '김승우', '려욱', '공민지', '다현', '고두심', '우원재', '이지아', '정인', '박지성', '김종국', '나르샤', '유재환']

# %%
for query in querys:
    image_download(query)
# Out:
# 케이윌 검색
# 케이윌 스크롤 중 .............
# 케이윌 찾은 이미지 개수: 70
# 1/70 케이윌 다운로드 중....... Download time : 0.0 초
# 2/70 케이윌 다운로드 중....... Download time : 0.0 초
# 3/70 케이윌 다운로드 중....... Download time : 0.0 초
# 4/70 케이윌 다운로드 중....... Download time : 0.0 초
# 5/70 케이윌 다운로드 중....... Download time : 0.0 초
# 6/70 케이윌 다운로드 중....... Download time : 0.0 초
# 7/70 케이윌 다운로드 중....... Download time : 0.0 초
# 8/70 케이윌 다운로드 중....... Download time : 0.0 초
# 9/70 케이윌 다운로드 중....... Download time : 0.0 초
# 10/70 케이윌 다운로드 중....... Download time : 0.0 초
# 11/70 케이윌 다운로드 중....... Download time : 0.0 초
# 12/70 케이윌 다운로드 중....... Download time : 0.0 초
# 13/70 케이윌 다운로드 중....... Download time : 0.0 초
# 14/70 케이윌 다운로드 중....... Download time : 0.0 초
# 15/70 케이윌 다운로드 중....... Download time : 0.0 초
# 16/70 케이윌 다운로드 중....... Download time : 0.0 초
# 17/70 케이윌 다운로드 중....... Download time : 0.0 초
# 18/70 케이윌 다운로드 중....... Download time : 0.0 초
# 19/70 케이윌 다운로드 중....... Download time : 0.0 초
# ...
